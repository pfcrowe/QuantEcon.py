# %% [markdown]
# ### The Task: Plotting a White Noise Process
#
# ### Version 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.random.randn(100)
plt.plot(x)
plt.show()

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
import numpy
numpy.sqrt(4)
# Out:
# 2.0

# %%
from numpy import sqrt

sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ### A Version with a For Loop

# %%
ts_length = 100
ϵ_values = [] # empty list

for i in range(ts_length):
    e = np.random.randn()
    ϵ_values.append(e)

plt.plot(ϵ_values)
plt.show()

# %% [markdown]
# ### Lists

# %%
x = [10, 'foo', False] # we can include heterogenous data in a list
type(x)
# Out:
# list

# %%
x
# Out:
# [10, 'foo', False]

# %%
x.append(2.5)

# %%
x
# Out:
# [10, 'foo', False, 2.5]

# %%
x
# Out:
# [10, 'foo', False, 2.5]

# %%
x.pop()
# Out:
# 2.5

# %%
x
# Out:
# [10, 'foo', False]

# %%
x[0]
# Out:
# 10

# %%
x[1]
# Out:
# 'foo'

# %% [markdown]
# ### The For Loop

# %%
for i in range(ts_length): # always use colon : before code block, 
    e = np.random.randn() # code blocks delimited by indentation 
    ϵ_values.append(e) # -> whitespace affects program, !cleans code up
    # indentation standard is 4 spaces
    # tab key needs to be configured to 4 spaces if using text editor/ide?
# Out:
#   File "<ipython-input-18-cd26e41efa23>", line 1
#     for i in range(ts:length):
#                      ^
# SyntaxError: invalid syntax

# %%
animals = ['dog', 'cat', 'bird']
for animal in animals:
    print("The plural of " + animal + " is " + animal + "s")
# Out:
# The plural of dog is dogs
# The plural of cat is cats
# The plural of bird is birds

# %%
for variable_name in sequence:
    <code block>
# Out:
#   File "<ipython-input-20-cf2abce2c345>", line 2
#     <code block>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### While loops

# %%
# for loop is most common means to iterate in python
ts_length = 100
ϵ_values = []
i = 0
while i < ts_length:
    e = np.random.randn()
    ϵ_values.append(e)
    i = i + 1 # i+= 1
plt.plot(ϵ_values)
plt.show()

# %% [markdown]
# ### User-Defined Functions

# %%
def generate_data(n):
    ϵ_values = []
    for i in range(n):
        e = np.random.randn()
        ϵ_values.append(e)
    return ϵ_values

data = generate_data(100)
plt.plot(data)
plt.show()

# %% [markdown]
# ### Conditions

# %%
def generate_data(n, generator_type):
    ϵ_values = []
    for i in range(n):
        if generator_type == 'U':
            e = np.random.uniform(0, 1)
        else:
            e = np.random.randn()
        ϵ_values.append(e)
    return ϵ_values

data = generate_data(100, 'U')
plt.plot(data)
plt.show()

# %%
def generate_data(n, generator_type):
    ϵ_values = []
    for i in range(n):
        e = generator_type() # generator_type bound to np.random.uniform
        ϵ_values.append(e)
    return ϵ_values

data = generate_data(100, np.random.uniform)
plt.plot(data)
plt.show()

# %%
max(7, 2, 4) # max() is a built-in Python function
# Out:
# 7

# %%
m = max # we can bind new names to functions
m(7, 2, 4) # therefore no problems passing a fn to an arg as a fn as above
# Out:
# 7

# %% [markdown]
# ### List Comprehensions

# %%
animals = ['dog', 'cat', 'bird']
plurals = [animal + 's' for animal in animals]
plurals
# Out:
# ['dogs', 'cats', 'birds']

# %%
range(8)
# Out:
# range(0, 8)

# %%
doubles = [2 * x for x in range(8)]
doubles
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
ϵ_values = []
for i in range(n):
    e = generator_type()
    ϵ_values.append(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f70772d07d12> in <module>
#       1 ϵ_values = []
# ----> 2 for i in range(n):
#       3     e = generator_type()
#       4     ϵ_values.append(e)
#
# NameError: name 'n' is not defined

# %%
ϵ_values = [generator_type() for i in range(n)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-97e06302210f> in <module>
# ----> 1 ϵ_values = [generator_type() for i in range(n)]
#
# NameError: name 'n' is not defined

# %% [markdown]
# ...
